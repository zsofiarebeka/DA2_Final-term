# %% [markdown]
# # <center> Data Analysis 2 - Final Term project</center>
# # <center> Seats held in the parliament by women on female secondary education rate, Gender Ineqality Index and Female labour force rate </center>
#
#
# <center>This study investigates the relationship between the % of seats held by women in parliaments and other socio-economic factors, like Gender Inequality Index (GII), Human Development Index (HDI), and data on the participation of men and women (separately) in the secondary education and the labour force accross 195 countries. With the help of regression models, it can be ecplored how these dimensions can be associated with the main dependent variable. The results show a strong positive correlation between women parliament seats(%) and secondary education participation rate and a negative correlation with the Gender Inequality Index.</center>

# %%
# Importing the libraries
import os
import sys
import warnings

import numpy as np
import pandas as pd
from mizani.formatters import percent_format
from plotnine import *
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy.stats import norm
import statsmodels.api as sm
import statsmodels.formula.api as smf
from mizani import transforms
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML
from patsy import dmatrices
# for lowess model method:
import statsmodels.nonparametric.kernel_regression as loess
from sklearn.metrics import mean_squared_error
from sklearn.metrics import log_loss

warnings.filterwarnings("ignore")

# %%
# Importing the prewritten helper functions
from py_helper_functions import *

# %%
# Importing the .csv file
# Try reading the file with different encodings
possible_encodings = ['utf-8', 'latin1', 'ISO-8859-1', 'utf-16']

for encoding in possible_encodings:
    try:
        df = pd.read_csv("gender_inequality_index.csv", encoding=encoding)
        print("File read successfully with encoding:", encoding)
        break
    except UnicodeDecodeError:
        print("Failed to read with encoding:", encoding)
# Out:
# Failed to read with encoding: utf-8
# File read successfully with encoding: latin1

# %% [markdown]
# The error I have encountered (UnicodeDecodeError: 'utf-8' codec can't decode byte...) typically occurs when there's an issue with the file encoding, meaning the characters in the file cannot be decoded using the specified encoding method (in this case, UTF-8). Therefore, I used latin1, also known as ISO/IEC 8859-1, encoding.
# However, the disadvantage of using latin1 is that it is only able to encompass characters from the latin alphabet, meanwhile UTF-8 is a variable-width character and is able to encode all 1,112,062 valid character code points in Unicode, using one to four one-byte (8-bit) code units.

# %%
# Importing the .csv file with latin1 encoding
df = pd.read_csv("gender_inequality_index.csv", encoding='latin1')
df
# Out:
#      HDI rank                              Country HUMAN DEVELOPMENT  \
# 0           1                          Switzerland         VERY HIGH
# 1           2                               Norway         VERY HIGH
# 2           3                              Iceland         VERY HIGH
# 3           4               Hong Kong, China (SAR)         VERY HIGH
# 4           5                            Australia         VERY HIGH
# ..        ...                                  ...               ...
# 190       191                          South Sudan               LOW
# 191       192  Korea (Democratic People's Rep. of)             OTHER
# 192       193                               Monaco             OTHER
# 193       194                                Nauru             OTHER
# 194       195                              Somalia             OTHER
#
#     GII VALUE GII RANK Maternal_mortality  Adolescent_birth_rate  \
# 0       0.018        3                  5                    2.2
# 1       0.016        2                  2                    2.3
# 2       0.043        8                  4                    5.4
# 3          ..       ..                 ..                    1.6
# 4       0.073       19                  6                    8.1
# ..        ...      ...                ...                    ...
# 190     0.587      150              1,150                   99.2
# 191        ..       ..                 89                    2.3
# 192        ..       ..                 ..                    7.2
# 193        ..       ..                 ..                   72.5
# 194        ..       ..                829                  118.0
#
#     Seats_parliamentt(% held by women) F_secondary_educ M_secondary_educ  \
# 0                                 39.8             96.9             97.5
# 1                                 45.0             99.1             99.3
# 2                                 47.6             99.8             99.7
# 3                                   ..             77.1             83.4
# 4                                 37.9             94.6             94.4
# ..                                 ...              ...              ...
# 190                               32.3             26.5             36.4
# 191                               17.6               ..               ..
# 192                               33.3               ..               ..
# 193                               10.5               ..               ..
# 194                               24.6               ..               ..
#
#     F_Labour_force M_Labour_force  Unnamed: 12
# 0             61.7           72.7          NaN
# 1             60.3           72.0          NaN
# 2             61.7           70.5          NaN
# 3             53.5           65.8          NaN
# 4             61.1           70.5          NaN
# ..             ...            ...          ...
# 190           70.4           73.6          NaN
# 191           77.2           86.1          NaN
# 192             ..             ..          NaN
# 193             ..             ..          NaN
# 194           20.9           47.0          NaN
#
# [195 rows x 13 columns]

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------
# ## 1. Introduction
#
# The underrepresentation of women is not a new phenomenon under the sun, in particular when it comes to roles with higher authorities.  One example are roles in the institutions of representative democracies, parliaments. Male majority in parliaments has been considered normal in the past decades, however female representation is gaining more and more attention and importance. As a woman, I find it particularly interesting and close to my heart to understand the factors that drive the change for equal representation of males and females in such institutions. There are several socio-economic factors that can be associated with this change, however female secondary education participation, a country's Gender Inequality Index and the female labour force participation are crucial benchmarks to assess female representation in parliaments across different countries.
#
# - My aim with this paper is to:
#
#     - Study the correlation between female secondary education participation rate and % of parliament seats held by women
#     - Study the correlation between female secondary education participation rate, Gender Inequality Index (GII) and  and % of parliament seats held by women
#     - Study the correlation between female secondary education participation rate, female labour force participation rate and % of parliament seats held by women
#     - Study the correlation between all of the abovementioned rates and indexes and % of parliament seats held by women
#     - Identify how countries vary in terms of gender representation in this legislative body
#     - To broaden the scope of understanding gender disparities: Study the distribution of Human Development Index (HDI) by Gender Inequality Index
#
# The expectations of the results include higher female secondary education and labour force participation rate increase the possibility of the number of seats held by women. Moreover, a higher GII is expected to decrease the % of seats held by women.
#
# -----------------------------------------------------------------------------------------------------------------------
# ## 2. Data
#
# The data used in this report was found on [Kaggle]("https://www.kaggle.com/datasets/rajkumarpandey02/world-data-of-gender-inequality-index"), but the original source is [Human Development Reports]("https://hdr.undp.org/data-center/documentation-and-downloads"), namely the *Table 5: Gender Inequality Index*. The dataset contains 195 rows and 13 columns, where data is categorized by countries and is ranked by the Human Development Index (HDI). Other variables include ranks, index values and % rates and the original data type of the columns are *object*. The dataset contains several missing values denoted as '..' or '...'. The dataset is representative of 2021, except for the maternal mortality ratio, which reflects 2017 - and is not needed for our analysis.
#
# For this study, data cleaning and wrangling was necessary before performing regression models. Besides renaming and reformatting and dropping unnecessary columns, I replaced the missing values with the correct *NaN* format and transformed the data types of the columns from object to float to be able to perform regression models. The data cleaning resulted in the following conclusions:
# - There are several missing values as the 'count' values are different
# - The dependent variable, "parliamentseatsheldbywomenrate" ranges from 0% to 55.7% and has 2 missing values
# - The explanatory variable, femalesecondaryeducation column has missing values (18, namely)
# - The first conditioning variable, female labour force ranges from 6 to 83.1 and has 15 missing values
# - The second conditioning variable, gender inequality index (GII) ranges from 0.013 to 0.82 (on a 0-1 scale) and has 25 missing values
# - In conclusion, we need to drop the rows where we have missing values in the variables that we carry out this analysis with
#
# Variables with explanation used for the regression analysis:
#
# - **Dependent variable (y)**: Share of seats in the parliament: Proportion of seats held by women in the national parliament expressed as a percentage of total seats. For countries with a bicameral legislative system, the share of seats is calculated based on both houses.
# - **Explanatory variable (x)**: Female secondary education: Percentage of the female population ages 25 and older that has reached (but not necessarily completed) a secondary level of education.
# - **Conditioning variable (z1)**: Gender Inequality Index: A composite measure reflecting inequality in achievement between women and men in three dimensions: reproductive health, empowerment and the labour market. The exact calculation of the index can be found [here]("https://hdr.undp.org/sites/default/files/2021-22_HDR/hdr2021-22_technical_notes.pdf").
# - **Conditioning variable (z2)**: Female labour force: Percentage of the female population ages 15 and older that participate in the labour force.
# - **Dummy variable**: To be able to perform a logistic regression, I needed to create a binary variable of the dependent variable, "seats held in the parliament by women". As it is a percentage rate, I created a binary outcome variable indicating whether the percentage of seats held by women is above or below a specific threshold. For instance:
#         - 1: Indicates that the percentage of seats held by women is above a certain threshold (25%)
#         - 0: Indicates that the percentage of seats held by women is below or equal to the threshold
#
# Other variables in the dataset:
# - Countries
# - Human Development Index indicators:
#     - HDI rank
#     - HDI level
# - Gender Inequality Index indicators:
#     - GII (z1)
#     - GII rank
# - Reproductive Health indicators:
#     - Maternal mortality ratio: Number of deaths due to pregnancy-related causes per 100,000 live births.
#     - Adolescent birth rate: Number of births to women ages 15–19 per 1,000 women ages 15–19.
# - % of seats in the parliament  held by women (y)
# - Educational indicators:
#     - Female secondary education rate
#     - Male secondary education rate
# - Workforce indicator:
#     - Female labour force participation (x)
#     - Male labour force participation

# %% [markdown]
# ## Data cleaning

# %%
# Replacing ' ' with '' in the column names for a more concise language and an easier filtering
df.rename(columns=lambda x: x.replace(' ', ''), inplace=True)

# Replaing '_' with '' in the column names for a more concise language and an easier filtering
df.rename(columns=lambda x: x.replace('_', ''), inplace=True)
df
# Out:
#      HDIrank                              Country HUMANDEVELOPMENT GIIVALUE  \
# 0          1                          Switzerland        VERY HIGH    0.018
# 1          2                               Norway        VERY HIGH    0.016
# 2          3                              Iceland        VERY HIGH    0.043
# 3          4               Hong Kong, China (SAR)        VERY HIGH       ..
# 4          5                            Australia        VERY HIGH    0.073
# ..       ...                                  ...              ...      ...
# 190      191                          South Sudan              LOW    0.587
# 191      192  Korea (Democratic People's Rep. of)            OTHER       ..
# 192      193                               Monaco            OTHER       ..
# 193      194                                Nauru            OTHER       ..
# 194      195                              Somalia            OTHER       ..
#
#     GIIRANK Maternalmortality  Adolescentbirthrate  \
# 0         3                 5                  2.2
# 1         2                 2                  2.3
# 2         8                 4                  5.4
# 3        ..                ..                  1.6
# 4        19                 6                  8.1
# ..      ...               ...                  ...
# 190     150             1,150                 99.2
# 191      ..                89                  2.3
# 192      ..                ..                  7.2
# 193      ..                ..                 72.5
# 194      ..               829                118.0
#
#     Seatsparliamentt(%heldbywomen) Fsecondaryeduc Msecondaryeduc FLabourforce  \
# 0                             39.8           96.9           97.5         61.7
# 1                             45.0           99.1           99.3         60.3
# 2                             47.6           99.8           99.7         61.7
# 3                               ..           77.1           83.4         53.5
# 4                             37.9           94.6           94.4         61.1
# ..                             ...            ...            ...          ...
# 190                           32.3           26.5           36.4         70.4
# 191                           17.6             ..             ..         77.2
# 192                           33.3             ..             ..           ..
# 193                           10.5             ..             ..           ..
# 194                           24.6             ..             ..         20.9
#
#     MLabourforce  Unnamed:12
# 0           72.7         NaN
# 1           72.0         NaN
# 2           70.5         NaN
# 3           65.8         NaN
# 4           70.5         NaN
# ..           ...         ...
# 190         73.6         NaN
# 191         86.1         NaN
# 192           ..         NaN
# 193           ..         NaN
# 194         47.0         NaN
#
# [195 rows x 13 columns]

# %%
# Converting the column names to lowercase
df.columns = df.columns.str.lower()
df
# Out:
#      hdirank                              country humandevelopment giivalue  \
# 0          1                          Switzerland        VERY HIGH    0.018
# 1          2                               Norway        VERY HIGH    0.016
# 2          3                              Iceland        VERY HIGH    0.043
# 3          4               Hong Kong, China (SAR)        VERY HIGH       ..
# 4          5                            Australia        VERY HIGH    0.073
# ..       ...                                  ...              ...      ...
# 190      191                          South Sudan              LOW    0.587
# 191      192  Korea (Democratic People's Rep. of)            OTHER       ..
# 192      193                               Monaco            OTHER       ..
# 193      194                                Nauru            OTHER       ..
# 194      195                              Somalia            OTHER       ..
#
#     giirank maternalmortality  adolescentbirthrate  \
# 0         3                 5                  2.2
# 1         2                 2                  2.3
# 2         8                 4                  5.4
# 3        ..                ..                  1.6
# 4        19                 6                  8.1
# ..      ...               ...                  ...
# 190     150             1,150                 99.2
# 191      ..                89                  2.3
# 192      ..                ..                  7.2
# 193      ..                ..                 72.5
# 194      ..               829                118.0
#
#     seatsparliamentt(%heldbywomen) fsecondaryeduc msecondaryeduc flabourforce  \
# 0                             39.8           96.9           97.5         61.7
# 1                             45.0           99.1           99.3         60.3
# 2                             47.6           99.8           99.7         61.7
# 3                               ..           77.1           83.4         53.5
# 4                             37.9           94.6           94.4         61.1
# ..                             ...            ...            ...          ...
# 190                           32.3           26.5           36.4         70.4
# 191                           17.6             ..             ..         77.2
# 192                           33.3             ..             ..           ..
# 193                           10.5             ..             ..           ..
# 194                           24.6             ..             ..         20.9
#
#     mlabourforce  unnamed:12
# 0           72.7         NaN
# 1           72.0         NaN
# 2           70.5         NaN
# 3           65.8         NaN
# 4           70.5         NaN
# ..           ...         ...
# 190         73.6         NaN
# 191         86.1         NaN
# 192           ..         NaN
# 193           ..         NaN
# 194         47.0         NaN
#
# [195 rows x 13 columns]

# %%
# Upon checking the df, the last column only contains NaN values
df["unnamed:12"].value_counts

# Dropping the last column with NaN values
df.drop(["unnamed:12"], axis=1, inplace = True)

# %%
df
# Out:
#      hdirank                              country humandevelopment giivalue  \
# 0          1                          Switzerland        VERY HIGH    0.018
# 1          2                               Norway        VERY HIGH    0.016
# 2          3                              Iceland        VERY HIGH    0.043
# 3          4               Hong Kong, China (SAR)        VERY HIGH       ..
# 4          5                            Australia        VERY HIGH    0.073
# ..       ...                                  ...              ...      ...
# 190      191                          South Sudan              LOW    0.587
# 191      192  Korea (Democratic People's Rep. of)            OTHER       ..
# 192      193                               Monaco            OTHER       ..
# 193      194                                Nauru            OTHER       ..
# 194      195                              Somalia            OTHER       ..
#
#     giirank maternalmortality  adolescentbirthrate  \
# 0         3                 5                  2.2
# 1         2                 2                  2.3
# 2         8                 4                  5.4
# 3        ..                ..                  1.6
# 4        19                 6                  8.1
# ..      ...               ...                  ...
# 190     150             1,150                 99.2
# 191      ..                89                  2.3
# 192      ..                ..                  7.2
# 193      ..                ..                 72.5
# 194      ..               829                118.0
#
#     seatsparliamentt(%heldbywomen) fsecondaryeduc msecondaryeduc flabourforce  \
# 0                             39.8           96.9           97.5         61.7
# 1                             45.0           99.1           99.3         60.3
# 2                             47.6           99.8           99.7         61.7
# 3                               ..           77.1           83.4         53.5
# 4                             37.9           94.6           94.4         61.1
# ..                             ...            ...            ...          ...
# 190                           32.3           26.5           36.4         70.4
# 191                           17.6             ..             ..         77.2
# 192                           33.3             ..             ..           ..
# 193                           10.5             ..             ..           ..
# 194                           24.6             ..             ..         20.9
#
#     mlabourforce
# 0           72.7
# 1           72.0
# 2           70.5
# 3           65.8
# 4           70.5
# ..           ...
# 190         73.6
# 191         86.1
# 192           ..
# 193           ..
# 194         47.0
#
# [195 rows x 12 columns]

# %%
# Renaming the columns
df.rename(columns={
    'hdirank': 'hdirank',
    'country': 'country',
    'humandevelopment': 'hdiindex',
    'giivalue': 'gii',
    'giirank': 'giirank',
    'maternalmortality': 'maternalmortalityrate',
    'adolescentbirthrate': 'adolescentbirthrate',
    'seatsparliamentt(%heldbywomen)': 'parliamentseatsheldbywomenrate',
    'fsecondaryeduc': 'femalesecondaryeducation',
    'msecondaryeduc': 'malesecondaryeducation',
    'flabourforce': 'femalelabourforce',
    'mlabourforce': 'malelabourforce'
}, inplace=True)
df
# Out:
#      hdirank                              country   hdiindex    gii giirank  \
# 0          1                          Switzerland  VERY HIGH  0.018       3
# 1          2                               Norway  VERY HIGH  0.016       2
# 2          3                              Iceland  VERY HIGH  0.043       8
# 3          4               Hong Kong, China (SAR)  VERY HIGH     ..      ..
# 4          5                            Australia  VERY HIGH  0.073      19
# ..       ...                                  ...        ...    ...     ...
# 190      191                          South Sudan        LOW  0.587     150
# 191      192  Korea (Democratic People's Rep. of)      OTHER     ..      ..
# 192      193                               Monaco      OTHER     ..      ..
# 193      194                                Nauru      OTHER     ..      ..
# 194      195                              Somalia      OTHER     ..      ..
#
#     maternalmortalityrate  adolescentbirthrate parliamentseatsheldbywomenrate  \
# 0                       5                  2.2                           39.8
# 1                       2                  2.3                           45.0
# 2                       4                  5.4                           47.6
# 3                      ..                  1.6                             ..
# 4                       6                  8.1                           37.9
# ..                    ...                  ...                            ...
# 190                 1,150                 99.2                           32.3
# 191                    89                  2.3                           17.6
# 192                    ..                  7.2                           33.3
# 193                    ..                 72.5                           10.5
# 194                   829                118.0                           24.6
#
#     femalesecondaryeducation malesecondaryeducation femalelabourforce  \
# 0                       96.9                   97.5              61.7
# 1                       99.1                   99.3              60.3
# 2                       99.8                   99.7              61.7
# 3                       77.1                   83.4              53.5
# 4                       94.6                   94.4              61.1
# ..                       ...                    ...               ...
# 190                     26.5                   36.4              70.4
# 191                       ..                     ..              77.2
# 192                       ..                     ..                ..
# 193                       ..                     ..                ..
# 194                       ..                     ..              20.9
#
#     malelabourforce
# 0              72.7
# 1              72.0
# 2              70.5
# 3              65.8
# 4              70.5
# ..              ...
# 190            73.6
# 191            86.1
# 192              ..
# 193              ..
# 194            47.0
#
# [195 rows x 12 columns]

# %%
# Replace '..' and '...' with NaN values as they are missing values
df.replace(['..', '...'], np.nan, inplace=True)
df
# Out:
#      hdirank                              country   hdiindex    gii giirank  \
# 0          1                          Switzerland  VERY HIGH  0.018       3
# 1          2                               Norway  VERY HIGH  0.016       2
# 2          3                              Iceland  VERY HIGH  0.043       8
# 3          4               Hong Kong, China (SAR)  VERY HIGH    NaN     NaN
# 4          5                            Australia  VERY HIGH  0.073      19
# ..       ...                                  ...        ...    ...     ...
# 190      191                          South Sudan        LOW  0.587     150
# 191      192  Korea (Democratic People's Rep. of)      OTHER    NaN     NaN
# 192      193                               Monaco      OTHER    NaN     NaN
# 193      194                                Nauru      OTHER    NaN     NaN
# 194      195                              Somalia      OTHER    NaN     NaN
#
#     maternalmortalityrate  adolescentbirthrate parliamentseatsheldbywomenrate  \
# 0                       5                  2.2                           39.8
# 1                       2                  2.3                           45.0
# 2                       4                  5.4                           47.6
# 3                     NaN                  1.6                            NaN
# 4                       6                  8.1                           37.9
# ..                    ...                  ...                            ...
# 190                 1,150                 99.2                           32.3
# 191                    89                  2.3                           17.6
# 192                   NaN                  7.2                           33.3
# 193                   NaN                 72.5                           10.5
# 194                   829                118.0                           24.6
#
#     femalesecondaryeducation malesecondaryeducation femalelabourforce  \
# 0                       96.9                   97.5              61.7
# 1                       99.1                   99.3              60.3
# 2                       99.8                   99.7              61.7
# 3                       77.1                   83.4              53.5
# 4                       94.6                   94.4              61.1
# ..                       ...                    ...               ...
# 190                     26.5                   36.4              70.4
# 191                      NaN                    NaN              77.2
# 192                      NaN                    NaN               NaN
# 193                      NaN                    NaN               NaN
# 194                      NaN                    NaN              20.9
#
#     malelabourforce
# 0              72.7
# 1              72.0
# 2              70.5
# 3              65.8
# 4              70.5
# ..              ...
# 190            73.6
# 191            86.1
# 192             NaN
# 193             NaN
# 194            47.0
#
# [195 rows x 12 columns]

# %%
# Remove commas (',') from the dataframe as it only facilitates readability but it conflicts with calculating the regression
df = df.replace(',', '', regex=True)
df
# Out:
#      hdirank                              country   hdiindex    gii giirank  \
# 0          1                          Switzerland  VERY HIGH  0.018       3
# 1          2                               Norway  VERY HIGH  0.016       2
# 2          3                              Iceland  VERY HIGH  0.043       8
# 3          4                Hong Kong China (SAR)  VERY HIGH    NaN     NaN
# 4          5                            Australia  VERY HIGH  0.073      19
# ..       ...                                  ...        ...    ...     ...
# 190      191                          South Sudan        LOW  0.587     150
# 191      192  Korea (Democratic People's Rep. of)      OTHER    NaN     NaN
# 192      193                               Monaco      OTHER    NaN     NaN
# 193      194                                Nauru      OTHER    NaN     NaN
# 194      195                              Somalia      OTHER    NaN     NaN
#
#     maternalmortalityrate  adolescentbirthrate parliamentseatsheldbywomenrate  \
# 0                       5                  2.2                           39.8
# 1                       2                  2.3                           45.0
# 2                       4                  5.4                           47.6
# 3                     NaN                  1.6                            NaN
# 4                       6                  8.1                           37.9
# ..                    ...                  ...                            ...
# 190                  1150                 99.2                           32.3
# 191                    89                  2.3                           17.6
# 192                   NaN                  7.2                           33.3
# 193                   NaN                 72.5                           10.5
# 194                   829                118.0                           24.6
#
#     femalesecondaryeducation malesecondaryeducation femalelabourforce  \
# 0                       96.9                   97.5              61.7
# 1                       99.1                   99.3              60.3
# 2                       99.8                   99.7              61.7
# 3                       77.1                   83.4              53.5
# 4                       94.6                   94.4              61.1
# ..                       ...                    ...               ...
# 190                     26.5                   36.4              70.4
# 191                      NaN                    NaN              77.2
# 192                      NaN                    NaN               NaN
# 193                      NaN                    NaN               NaN
# 194                      NaN                    NaN              20.9
#
#     malelabourforce
# 0              72.7
# 1              72.0
# 2              70.5
# 3              65.8
# 4              70.5
# ..              ...
# 190            73.6
# 191            86.1
# 192             NaN
# 193             NaN
# 194            47.0
#
# [195 rows x 12 columns]

# %%
# Adding a new HDI column assigning values with the level of Human Development Index
df.hdiindex.value_counts()
# Out:
# VERY HIGH    66
# HIGH         49
# MEDIUM       44
# LOW          32
# OTHER         4
# Name: hdiindex, dtype: int64

# %%
# Adding (mapping) a new HDI column with numerical evaluations (1 = OTHER, 2 = LOW, 3 = MEDIUM, 4 = HIGH, 5 = VERY HIGH)
hdi_eva = {
    'OTHER': 1,
    'LOW': 2,
    'MEDIUM': 3,
    'HIGH': 4,
    'VERY HIGH': 5
}

# Creating a new column 'hdievaluation' based on the mapping
df['hdievaluation'] = df['hdiindex'].map(hdi_eva)
df
# Out:
#      hdirank                              country   hdiindex    gii giirank  \
# 0          1                          Switzerland  VERY HIGH  0.018       3
# 1          2                               Norway  VERY HIGH  0.016       2
# 2          3                              Iceland  VERY HIGH  0.043       8
# 3          4                Hong Kong China (SAR)  VERY HIGH    NaN     NaN
# 4          5                            Australia  VERY HIGH  0.073      19
# ..       ...                                  ...        ...    ...     ...
# 190      191                          South Sudan        LOW  0.587     150
# 191      192  Korea (Democratic People's Rep. of)      OTHER    NaN     NaN
# 192      193                               Monaco      OTHER    NaN     NaN
# 193      194                                Nauru      OTHER    NaN     NaN
# 194      195                              Somalia      OTHER    NaN     NaN
#
#     maternalmortalityrate  adolescentbirthrate parliamentseatsheldbywomenrate  \
# 0                       5                  2.2                           39.8
# 1                       2                  2.3                           45.0
# 2                       4                  5.4                           47.6
# 3                     NaN                  1.6                            NaN
# 4                       6                  8.1                           37.9
# ..                    ...                  ...                            ...
# 190                  1150                 99.2                           32.3
# 191                    89                  2.3                           17.6
# 192                   NaN                  7.2                           33.3
# 193                   NaN                 72.5                           10.5
# 194                   829                118.0                           24.6
#
#     femalesecondaryeducation malesecondaryeducation femalelabourforce  \
# 0                       96.9                   97.5              61.7
# 1                       99.1                   99.3              60.3
# 2                       99.8                   99.7              61.7
# 3                       77.1                   83.4              53.5
# 4                       94.6                   94.4              61.1
# ..                       ...                    ...               ...
# 190                     26.5                   36.4              70.4
# 191                      NaN                    NaN              77.2
# 192                      NaN                    NaN               NaN
# 193                      NaN                    NaN               NaN
# 194                      NaN                    NaN              20.9
#
#     malelabourforce  hdievaluation
# 0              72.7              5
# 1              72.0              5
# 2              70.5              5
# 3              65.8              5
# 4              70.5              5
# ..              ...            ...
# 190            73.6              2
# 191            86.1              1
# 192             NaN              1
# 193             NaN              1
# 194            47.0              1
#
# [195 rows x 13 columns]

# %%
# Putting the column names in a dictionary for type inspection
columns_of_interest = [
    'gii', 'giirank',
    'maternalmortalityrate', 'parliamentseatsheldbywomenrate',
    'femalesecondaryeducation', 'malesecondaryeducation', 'femalelabourforce', 'malelabourforce', "hdievaluation"
]

# Printing the data types of specified columns
for col in columns_of_interest:
    print(f"Column '{col}' has data type: {df[col].dtype}")
# Out:
# Column 'gii' has data type: object
# Column 'giirank' has data type: object
# Column 'maternalmortalityrate' has data type: object
# Column 'parliamentseatsheldbywomenrate' has data type: object
# Column 'femalesecondaryeducation' has data type: object
# Column 'malesecondaryeducation' has data type: object
# Column 'femalelabourforce' has data type: object
# Column 'malelabourforce' has data type: object
# Column 'hdievaluation' has data type: int64

# %%
# Converting the object type columns to float
for col in columns_of_interest:
    df[col] = df[col].astype(float)

# %%
# Checking the data types of specified columns
for col in columns_of_interest:
    print(f"Column '{col}' has data type: {df[col].dtype}")
# Out:
# Column 'gii' has data type: float64
# Column 'giirank' has data type: float64
# Column 'maternalmortalityrate' has data type: float64
# Column 'parliamentseatsheldbywomenrate' has data type: float64
# Column 'femalesecondaryeducation' has data type: float64
# Column 'malesecondaryeducation' has data type: float64
# Column 'femalelabourforce' has data type: float64
# Column 'malelabourforce' has data type: float64
# Column 'hdievaluation' has data type: float64

# %%
# Checking the distribution of numeric values
df.loc[:, ["gii", "maternalmortalityrate", "adolescentbirthrate","parliamentseatsheldbywomenrate", "femalesecondaryeducation",
           "malesecondaryeducation", "femalelabourforce", "malelabourforce", "hdievaluation"]].describe()
# Out:
#               gii  maternalmortalityrate  adolescentbirthrate  \
# count  170.000000             184.000000           195.000000
# mean     0.344376             160.027174            44.597949
# std      0.197105             233.028867            38.422479
# min      0.013000               2.000000             1.600000
# 25%      0.177500              12.750000            10.750000
# 50%      0.363000              53.000000            36.200000
# 75%      0.505750             188.250000            64.200000
# max      0.820000            1150.000000           170.500000
#
#        parliamentseatsheldbywomenrate  femalesecondaryeducation  \
# count                      193.000000                177.000000
# mean                        24.701554                 62.706780
# std                         12.404319                 29.528487
# min                          0.000000                  6.400000
# 25%                         16.500000                 37.700000
# 50%                         23.600000                 69.900000
# 75%                         33.600000                 90.200000
# max                         55.700000                100.000000
#
#        malesecondaryeducation  femalelabourforce  malelabourforce  \
# count              177.000000         180.000000       180.000000
# mean                67.068362          50.224444        69.863333
# std                 26.450033          15.905491         9.012734
# min                 13.000000           6.000000        43.900000
# 25%                 44.800000          42.400000        65.050000
# 50%                 71.200000          52.150000        69.350000
# 75%                 92.500000          60.475000        75.525000
# max                100.000000          83.100000        95.500000
#
#        hdievaluation
# count     195.000000
# mean        3.723077
# std         1.155547
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000

# %%
# Dropping NaN values from specific columns
columns_to_drop_na = ['gii', 'parliamentseatsheldbywomenrate', 'femalesecondaryeducation', 'femalelabourforce']
cleaned_df = df.dropna(subset=columns_to_drop_na)
cleaned_df
# Out:
#      hdirank                   country   hdiindex    gii  giirank  \
# 0          1               Switzerland  VERY HIGH  0.018      3.0
# 1          2                    Norway  VERY HIGH  0.016      2.0
# 2          3                   Iceland  VERY HIGH  0.043      8.0
# 4          5                 Australia  VERY HIGH  0.073     19.0
# 5          6                   Denmark  VERY HIGH  0.013      1.0
# ..       ...                       ...        ...    ...      ...
# 186      187                   Burundi        LOW  0.505    127.0
# 187      188  Central African Republic        LOW  0.672    166.0
# 188      189                     Niger        LOW  0.611    153.0
# 189      190                      Chad        LOW  0.652    165.0
# 190      191               South Sudan        LOW  0.587    150.0
#
#      maternalmortalityrate  adolescentbirthrate  \
# 0                      5.0                  2.2
# 1                      2.0                  2.3
# 2                      4.0                  5.4
# 4                      6.0                  8.1
# 5                      4.0                  1.9
# ..                     ...                  ...
# 186                  548.0                 53.6
# 187                  829.0                160.5
# 188                  509.0                170.5
# 189                 1140.0                138.3
# 190                 1150.0                 99.2
#
#      parliamentseatsheldbywomenrate  femalesecondaryeducation  \
# 0                              39.8                      96.9
# 1                              45.0                      99.1
# 2                              47.6                      99.8
# 4                              37.9                      94.6
# 5                              39.7                      95.1
# ..                              ...                       ...
# 186                            38.9                       7.8
# 187                            12.9                      13.9
# 188                            25.9                       9.2
# 189                            32.3                       7.7
# 190                            32.3                      26.5
#
#      malesecondaryeducation  femalelabourforce  malelabourforce  hdievaluation
# 0                      97.5               61.7             72.7            5.0
# 1                      99.3               60.3             72.0            5.0
# 2                      99.7               61.7             70.5            5.0
# 4                      94.4               61.1             70.5            5.0
# 5                      95.2               57.7             66.7            5.0
# ..                      ...                ...              ...            ...
# 186                    13.0               79.0             77.4            2.0
# 187                    31.6               63.3             79.5            2.0
# 188                    15.2               61.7             84.3            2.0
# 189                    24.4               46.9             69.9            2.0
# 190                    36.4               70.4             73.6            2.0
#
# [170 rows x 13 columns]

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------
# ## 3. Models
#
# ### Model 1: % of seats held by women in the parliament on female secondary education rate
#
# $parliamentseats=\beta_0+\beta_1 x_1 x femalesecondaryeducation$
#
# Model 1 is a simple linear regression of % of seats held by women in the parliament on female secondary education rate. The regression table can be found at **Appendix A1**. According to the $\beta_1$ of the model, females with secondary education have 6.4% more probability, on average to earn seats in the parliament. R-squared is 0.023 which means that approximately 2.3% of the variation in the percentage of seats held by women in parliament can be explained by the variation in female secondary education rate. The confidence interval of the slope is [0.001;0.126] which does not include zero. This means that we can be 95% confident that the true effect of the female secondary education rate on the percentage of seats held by women in parliament is between 0.1% and 12.6%. This means that we can still rule out - with a 95% confidence level - the possibility that the effect of female secondary education on the percentage of seats held by women in parliament is zero or has no impact. The p-value < 0.05 also proves the above statement.
#
# To identify a potential nonlinear relationship, I created a regression graph with the lowess method. (**Appendix A2**) According to the chart, there is a slight decrease in the seats between 40% and 60% of female secondary education rate, which is not visible in the simple linear regression.

# %%
# Creating the regression using robust std with HC1
reg1 = smf.ols(formula="parliamentseatsheldbywomenrate~femalesecondaryeducation", data=df).fit(cov_type="HC1")

# %%
# Creating the scatter plot with the regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=df['femalesecondaryeducation'], y=df['parliamentseatsheldbywomenrate'], scatter_kws={'alpha':0.5}, line_kws={'color':'red'})

# Customizing the titles and labels
plt.title("""Female Secondary Education's role in the % of parliament seats held by women""")
plt.xlabel('Female Secondary Education Rate')
plt.ylabel('Parliament Seats Held by Women Rate')

# Showing the plot
plt.show()

# %% [markdown]
# ### Model 2: % of seats held by women in the parliament on female secondary education rate and GII (z1)
#
# $parliamentseats=\beta_0 + \beta_1 femalesecondaryeducation + \beta_2 GII$
#
# The second model studies how the female secondary education and the Gender Inequality Index combined have an overall impact on the seats held in the parliament. (**Appendix B1**) All covariates are significant at 99%. $\beta_1$ of this model indicates that for a one-unit increase in female secondary education rates, and while holding the GII constant, the model predicts a decrease in the percentage of seats held by women in parliament by 0.208 units. The confidence interval of the slope is [-0.295;-0.121] which does not include zero. Conditioning on z1, $\beta_2$ of this model suggests that for a one-unit increase in the GII, and while holding female secondary education constant, the model predicts a decrease in the percentage of seats held by women in parliament by 52.114 units. The confidence interval of the slope is [-64.674;-39.553] which does not include zero. The two CIs don' overlap, suggesting a statistically significant difference. The robust SE of this coefficient is significantly higher (6.409) than the SE of $\beta_1$. R-squared is higher than the R-squared only considering the female secondary education (0.259), meaning that by taking GII into consideration, we increase out model's goodness of fit.

# %%
# Creating the regressions with the dependent and z1 conditioning variables
reg2 = smf.ols(formula="parliamentseatsheldbywomenrate~femalesecondaryeducation+gii", data=df).fit(cov_type="HC1")

# %% [markdown]
# ### Model 3: % of seats held by women in the parliament on female secondary education rate and female labour force rate (z2)
#
# $parliamentseats=\beta_0 + \beta_1 femalesecondaryeducation + \beta_2 femalelabourforce$
#
# The third model examines how the female secondary education and the Female labour force pariticipation rate combined have an overall impact on the seats held in the parliament. (**Appendix B2**) All covariates are significant at 99% except for $\beta_0$ which is significant at 95%. $\beta_1$ siggest that for a one-unit increase in female secondary education rates, and while holding the the female labour force rate constant, the model predicts a 8.2% increase in the percentage of seats held by women in parliament. The confidence interval of the slope is [0.023;0.142] which does not include zero. $\beta_2$ suggests that for a one-unit increase in the female labour force, and while holding female secondary education constant, the model predicts a 24.1% increase in the percentage of seats held by women in parliament. The confidence interval of the slope is [0.130;0.352] which does not include zero. This means that we can be 95% confident that the true effect of the of the female labour force rate, while holding the female secondary education rate constant, on the percentage of seats held by women in parliament is between 13% and 35.2%. R-squared is higher than the R-squared only considering the fmemale secondary education (0.106). This means that by taking the female labour force into consideration, we increase out model's goodness of fit. However, it is not higher when we take the GII into consideration(0.259).

# %%
# Creating the regressions with the dependent and z2 conditioning variables
reg3 = smf.ols(formula="parliamentseatsheldbywomenrate~femalesecondaryeducation+femalelabourforce", data=df).fit(cov_type="HC1")

# %% [markdown]
# ### Model 4: % of seats held by women in the parliament on female secondary education rate, GII (z1) and female labour force rate (z2)
#
# $parliamentseats=\beta_0 + \beta_1 femalesecondaryeducation + \beta_2 GII + \beta_3 femalelabourforce$
#
# This model challenges the assumptions about the direct relationships between education, gender inequality, female labor force participation, and the percentage of women holding seats in parliament, examining whether these factors independently or collectively influence political representation. (**Appendix C**) All covariates are significant at 99%. $\beta_1$ indicates that the model predicts a 17.4% increase in the percentage of seats held by women in parliament. The confidence interval of the slope is [-0.259;-0.088] which does not include zero. None of the confidence intervals overlap, indicating a statistically significant difference between the variables. (**Appendix C1**) This particular regression model exhibits the highest R-squared value among all the examined models, indicating the strongest explanatory power in explaining the variation (0.299). This means that by taking the Gender Inequality Index and the female labour force participation rate into consideration, we increase out model's goodness of fit.

# %%
# Creating the regressions with the dependent and both (z1 and z2) conditioning variables
reg4 = smf.ols(formula="parliamentseatsheldbywomenrate~femalesecondaryeducation+gii+femalelabourforce", data=df).fit(cov_type="HC1")

# %% [markdown]
# ## Interpreting coefficients in the *fourth* column:
#
# - $\beta_1$: For a one-unit increase in female secondary education rates, and while holding the the female labour force rate and GII constant, the model predicts a 17.4% increase in the percentage of seats held by women in parliament. The confidence interval of the slope is [-0.259;-0.088] which does not include zero.
#
# - $\beta_2$:  For a one-unit increase in the GII, while holding female secondary education and female labour force constant, the model predicts a 17.4% decrease in the percentage of seats held by women in parliament. The confidence interval of the slope is [-59.472;-34.660] which does not include zero. This means that we can be 95% confident that the true effect of the of the Gender Inequality Index, while holding the female secondary education and female labour force constant, on the percentage of seats held by women in parliament is between ******************.
#
# - $\beta_3$: For a one-unit increase in the female labor force participation rate, holding GII and female secondary education constant, the model predicts a 14.9% increase in the percentage of seats held by women in parliament. The confidence interval of the slope is [0.049;0.248] which does not include zero. This means that we can be 95% confident that the true effect of the of the female labour force rate, while holding the female secondary education and GII constant, on the percentage of seats held by women in parliament is between 4.9% and 24.8%.
#
# - All covariates are significant at 99%.
#
# - This particular regression model exhibits the highest R-squared value among all the examined models, indicating the strongest explanatory power in explaining the variation (0.299). This means that by taking the Gender Inequality Index and the female labour force participation rate into consideration, we increase out model's goodness of fit.

# %%
# Checking the regression comparison table with Stargazer
stargazer = Stargazer([reg1, reg2, reg3, reg4])
stargazer.covariate_order(["femalesecondaryeducation", "gii", "femalelabourforce", "Intercept"])
stargazer.rename_covariates({"Intercept": "Constant"})
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: parliamentseatsheldbywomenrate</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">femalesecondaryeducation</td><td>0.064<sup>**</sup></td><td>-0.208<sup>***</sup></td><td>0.082<sup>***</sup></td><td>-0.174<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.032)</td><td>(0.044)</td><td>(0.030)</td><td>(0.044)</td></tr>
# <tr><td style="text-align:left">gii</td><td></td><td>-52.114<sup>***</sup></td><td></td><td>-47.066<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(6.409)</td><td></td><td>(6.330)</td></tr>
# <tr><td style="text-align:left">femalelabourforce</td><td></td><td></td><td>0.241<sup>***</sup></td><td>0.149<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.057)</td><td>(0.051)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>21.163<sup>***</sup></td><td>56.178<sup>***</sup></td><td>8.056<sup>**</sup></td><td>44.811<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(2.269)</td><td>(4.894)</td><td>(3.617)</td><td>(5.936)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>175</td><td>170</td><td>170</td><td>170</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.023</td><td>0.267</td><td>0.117</td><td>0.299</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.017</td><td>0.259</td><td>0.106</td><td>0.286</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>12.432 (df=173)</td><td>10.636 (df=167)</td><td>11.676 (df=167)</td><td>10.437 (df=166)</td></tr><tr><td style="text-align: left">F Statistic</td><td>3.961<sup>**</sup> (df=1; 173)</td><td>40.071<sup>***</sup> (df=2; 167)</td><td>12.372<sup>***</sup> (df=2; 167)</td><td>30.393<sup>***</sup> (df=3; 166)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
# Creating the scatter plot with the regression line
plt.figure(figsize=(8, 6))
sns.regplot(x=df['femalesecondaryeducation'], y=df['parliamentseatsheldbywomenrate'], scatter_kws={'alpha':0.5}, line_kws={'color':'red'})

# adding titles and labels
plt.title("""Female Secondary Education's role in the % of parliament seats held by women""")
plt.xlabel('Female Secondary Education Rate')
plt.ylabel('Parliament Seats Held by Women Rate')

# show the plot
plt.show()

# %%
# Setting the chart size
plt.figure(figsize=(8, 6))

# Creating a KDE plot
sns.kdeplot(data = cleaned_df, x = "gii", hue = "hdiindex",
           palette = 'viridis',
           fill = True,
           alpha = 0.4,
           multiple="stack")

# Setting labels and title
plt.xlabel("Gender Inequality Index")
plt.ylabel("Human Development Index")
plt.title("Kernel Density Estimation of Gender Inequality Index by Human Development Index level")
plt.show()

# %% [markdown]
# # Probability calculation

# %% [markdown]
# ## Linear probability model (LPM)

# %%
# Dropping rows with NaN values in any column
cleaned_df = df.dropna()

# Generating predictions for the cleaned dataset
cleaned_df["pred_lpm4"] = reg4.predict(cleaned_df)
cleaned_df

# %%
# Checking the spread of the predicted values (min, max)
cleaned_df["pred_lpm4"].describe().round(4)

# %% [markdown]
# - The spread of the prediction goes well above 1 (39.3141) which means that we need to use logit and probit models to get accurate predicted probability values.

# %% [markdown]
# ## Logit model

# %%
cleaned_df.parliamentseatsheldbywomenrate.describe()

# Based on the values, we can conclude that the maximum percentage is 55.7%, therefore it makes sense to set the threshold to 25%

# %%
# Creating a binary variable based on the threshold (25%)
threshold = 25
cleaned_df['above_threshold'] = (cleaned_df['parliamentseatsheldbywomenrate'] > threshold).astype(int)
cleaned_df

# %%
# Estimating the logit model of reg4
y, X = dmatrices(
    "above_threshold ~ femalesecondaryeducation + gii + femalelabourforce",
    cleaned_df,
)
logit_mod = sm.Logit(y, X)
logit_res = logit_mod.fit()
logit_margeff_results = logit_res.get_margeff()
logit_margeff_results.summary()

# %% [markdown]
# # Interpretation for logit
#
# - A one-unit increase in female secondary education is associated with an approximate decrease of 0.0063 in the log odds of being above the threshold (holding other variables constant). The effect is statistically significant (p < 0.05)
# - A one-unit increase in the Gender Inequality Index (GII) is associated with an approximate decrease of 1.5492 in the log odds of being above the threshold (holding other variables constant). The effect is highly statistically significant (p < 0.001).
# - A one-unit increase in female labor force participation rate is associated with an approximate increase of 0.0051 in the log odds of being above the threshold (holding other variables constant). The effect is statistically significant (p < 0.05).

# %% [markdown]
# ## Probit model

# %%
# Estimating the probit model of reg4
probit = sm.Probit(y, X)
probit_res = probit.fit()
probit_margeff_results = probit_res.get_margeff()
probit_margeff_results.summary()

# %% [markdown]
# ## Interpretation for probit
# - Almost same results as the results of logit and both are very similar to lpm, which was expected.

# %%
cleaned_df["pred_probit"] = probit_res.predict()
cleaned_df["pred_logit"] = logit_res.predict()
cleaned_df

# %%
cleaned_df.pred_probit.describe()

# %%
cleaned_df.pred_logit.describe()

# %%
p1 = pd.DataFrame(
    {
        "Brier-score": [
            mean_squared_error(cleaned_df["above_threshold"], cleaned_df["pred_lpm4"]),
            mean_squared_error(cleaned_df["above_threshold"], cleaned_df["pred_logit"]),
            mean_squared_error(cleaned_df["above_threshold"], cleaned_df["pred_probit"]),
        ], "Log-loss": [
            -1 * log_loss(cleaned_df["above_threshold"], cleaned_df["pred_lpm4"]),
            -1 * log_loss(cleaned_df["above_threshold"], cleaned_df["pred_logit"]),
            -1 * log_loss(cleaned_df["above_threshold"], cleaned_df["pred_probit"]),
        ],
    },
    index=["LPM", "Logit", "Probit"],
).T.round(4)

p1

# %% [markdown]
# # Interpreting goodness of fit measures
#
# - The Brier scores suggest that the models perform very similarly, with logit (0.2011) and probit (0.2012) providing the best fit.
# - LPM has a higher Brier score of 659.618 suggesting a significantly worse fit.
# - The log-loss values of each model show the similar ordering: logit and probit model show very similar results (-0.5855 and -0.5852 respectively).
# - LPM has a higher log-loss absolue value, performing lower than logit and probit.
# - The prediction values of only the logit and probit models are correctly bound between 0 and 1.

# %%
# Creating the DataFrame with input range and predicted values
# (replace 'input_values' with the appropriate range of inputs for your models)
data = pd.DataFrame({'input_values': cleaned_df["above_threshold"],
                     'logit_prediction': cleaned_df["pred_logit"],
                     'probit_prediction': cleaned_df["pred_probit"],
                     'lpm_prediction': cleaned_df["pred_lpm4"]})

# Melt the DataFrame to long format for plotting
melted_data = data.melt('input_values', var_name='Model', value_name='Predicted')

# Use ggplot to plot the lines for logit, probit, and LPM
p = (
    ggplot(melted_data, aes(x='input_values', y='Predicted', color='Model'))
    + geom_line(size=1)
    + labs(x='Input', y='Predicted Values')
    + theme_bw()
    # Add other customization as needed
)

# Display the plot
print(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 # Creating the DataFrame with input range and predicted values
#       2 # (replace 'input_values' with the appropriate range of inputs for your models)
# ----> 3 data = pd.DataFrame({'input_values': cleaned_df["above_threshold"],
#       4                      'logit_prediction': cleaned_df["pred_logit"],
#       5                      'probit_prediction': cleaned_df["pred_probit"],
#       6                      'lpm_prediction': cleaned_df["pred_lpm4"]})
#       8 # Melt the DataFrame to long format for plotting
#       9 melted_data = data.melt('input_values', var_name='Model', value_name='Predicted')
#
# NameError: name 'cleaned_df' is not defined

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------
# ## 4. Conclusion
#
#
# ## 5. Main summary and limitations
#
#
# -----------------------------------------------------------------------------------------------------------------------
# ## References

# %% [markdown]
# ## Appendices
#
# ### Appendix A1. (Model 1)

# %%
reg1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     parliamentseatsheldbywomenrate   R-squared:                       0.023
# Model:                                        OLS   Adj. R-squared:                  0.017
# Method:                             Least Squares   F-statistic:                     3.961
# Date:                            Wed, 20 Dec 2023   Prob (F-statistic):             0.0481
# Time:                                    21:35:13   Log-Likelihood:                -688.35
# No. Observations:                             175   AIC:                             1381.
# Df Residuals:                                 173   BIC:                             1387.
# Df Model:                                       1
# Covariance Type:                              HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   21.1628      2.269      9.326      0.000      16.715      25.611
# femalesecondaryeducation     0.0636      0.032      1.990      0.047       0.001       0.126
# ==============================================================================
# Omnibus:                        4.409   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.110   Jarque-Bera (JB):                3.342
# Skew:                           0.210   Prob(JB):                        0.188
# Kurtosis:                       2.469   Cond. No.                         162.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# ### Appendix A2.

# %%
# Creating the scatter plot with the regression line with the lowess method
plt.figure(figsize=(10, 6))
sns.regplot(x=df['femalesecondaryeducation'], y=df['parliamentseatsheldbywomenrate'], lowess = True, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})

# Customizing the titles and labels
plt.title("""Female Secondary Education's role in the % of parliament seats held by women with the Lowess method""")
plt.xlabel('Female Secondary Education Rate')
plt.ylabel('Parliament Seats Held by Women Rate')

# Showing the plot
plt.show()

# %% [markdown]
# ### Appendix B1

# %%
reg2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     parliamentseatsheldbywomenrate   R-squared:                       0.267
# Model:                                        OLS   Adj. R-squared:                  0.259
# Method:                             Least Squares   F-statistic:                     40.07
# Date:                            Wed, 20 Dec 2023   Prob (F-statistic):           6.11e-15
# Time:                                    21:51:23   Log-Likelihood:                -641.62
# No. Observations:                             170   AIC:                             1289.
# Df Residuals:                                 167   BIC:                             1299.
# Df Model:                                       2
# Covariance Type:                              HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   56.1784      4.894     11.479      0.000      46.586      65.770
# femalesecondaryeducation    -0.2083      0.044     -4.686      0.000      -0.295      -0.121
# gii                        -52.1136      6.409     -8.132      0.000     -64.674     -39.553
# ==============================================================================
# Omnibus:                        2.486   Durbin-Watson:                   1.635
# Prob(Omnibus):                  0.289   Jarque-Bera (JB):                2.240
# Skew:                           0.280   Prob(JB):                        0.326
# Kurtosis:                       3.053   Cond. No.                         726.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# ### Appendix B2

# %%
reg3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     parliamentseatsheldbywomenrate   R-squared:                       0.117
# Model:                                        OLS   Adj. R-squared:                  0.106
# Method:                             Least Squares   F-statistic:                     12.37
# Date:                            Wed, 20 Dec 2023   Prob (F-statistic):           9.76e-06
# Time:                                    23:17:07   Log-Likelihood:                -657.49
# No. Observations:                             170   AIC:                             1321.
# Df Residuals:                                 167   BIC:                             1330.
# Df Model:                                       2
# Covariance Type:                              HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                    8.0559      3.617      2.227      0.026       0.966      15.146
# femalesecondaryeducation     0.0823      0.030      2.716      0.007       0.023       0.142
# femalelabourforce            0.2411      0.057      4.249      0.000       0.130       0.352
# ==============================================================================
# Omnibus:                        3.931   Durbin-Watson:                   1.684
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                3.405
# Skew:                           0.257   Prob(JB):                        0.182
# Kurtosis:                       2.534   Cond. No.                         352.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """

# %% [markdown]
# ### Appendix C

# %%
stargazer
# Out:
# <table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: parliamentseatsheldbywomenrate</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">femalesecondaryeducation</td><td>0.064<sup>**</sup></td><td>-0.208<sup>***</sup></td><td>0.082<sup>***</sup></td><td>-0.174<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.032)</td><td>(0.044)</td><td>(0.030)</td><td>(0.044)</td></tr>
# <tr><td style="text-align:left">gii</td><td></td><td>-52.114<sup>***</sup></td><td></td><td>-47.066<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(6.409)</td><td></td><td>(6.330)</td></tr>
# <tr><td style="text-align:left">femalelabourforce</td><td></td><td></td><td>0.241<sup>***</sup></td><td>0.149<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.057)</td><td>(0.051)</td></tr>
# <tr><td style="text-align:left">Constant</td><td>21.163<sup>***</sup></td><td>56.178<sup>***</sup></td><td>8.056<sup>**</sup></td><td>44.811<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(2.269)</td><td>(4.894)</td><td>(3.617)</td><td>(5.936)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>175</td><td>170</td><td>170</td><td>170</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.023</td><td>0.267</td><td>0.117</td><td>0.299</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.017</td><td>0.259</td><td>0.106</td><td>0.286</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>12.432 (df=173)</td><td>10.636 (df=167)</td><td>11.676 (df=167)</td><td>10.437 (df=166)</td></tr><tr><td style="text-align: left">F Statistic</td><td>3.961<sup>**</sup> (df=1; 173)</td><td>40.071<sup>***</sup> (df=2; 167)</td><td>12.372<sup>***</sup> (df=2; 167)</td><td>30.393<sup>***</sup> (df=3; 166)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# ### Appendix C1

# %%
reg4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     parliamentseatsheldbywomenrate   R-squared:                       0.299
# Model:                                        OLS   Adj. R-squared:                  0.286
# Method:                             Least Squares   F-statistic:                     30.39
# Date:                            Wed, 20 Dec 2023   Prob (F-statistic):           1.03e-15
# Time:                                    23:21:07   Log-Likelihood:                -637.90
# No. Observations:                             170   AIC:                             1284.
# Df Residuals:                                 166   BIC:                             1296.
# Df Model:                                       3
# Covariance Type:                              HC1
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   44.8109      5.936      7.548      0.000      33.176      56.446
# femalesecondaryeducation    -0.1738      0.044     -3.977      0.000      -0.259      -0.088
# gii                        -47.0661      6.330     -7.436      0.000     -59.472     -34.660
# femalelabourforce            0.1487      0.051      2.924      0.003       0.049       0.248
# ==============================================================================
# Omnibus:                        3.397   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.183   Jarque-Bera (JB):                3.014
# Skew:                           0.316   Prob(JB):                        0.222
# Kurtosis:                       3.162   Cond. No.                         978.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# """
